# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1]
print(PROJECT_ROOT)
# Out:
# /Users/florianb/Downloads/ai-customer-insights-engine

# %%
from src.rag import reranker as reranker_module

#from config import config

# %%
import importlib

#importlib.reload(config)
importlib.reload(reranker_module)
# Out:
# <module 'src.rag.reranker' from '/Users/florianb/Downloads/ai-customer-insights-engine/src/rag/reranker.py'>

# %% [markdown]
# ### Validation de `create_reranker()`

# %%
reranker = reranker_module.create_reranker(
    model_name="BAAI/bge-reranker-v2-m3",
    top_n=5,
)

# %%
type(reranker)
# Out:
# langchain_classic.retrievers.document_compressors.cross_encoder_rerank.CrossEncoderReranker

# %%
reranker.model
# Out:
# HuggingFaceCrossEncoder(client=<sentence_transformers.cross_encoder.CrossEncoder.CrossEncoder object at 0x105a2e650>, model_name='BAAI/bge-reranker-v2-m3', model_kwargs={})

# %%
reranker.top_n
# Out:
# 5
