# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1]
print(PROJECT_ROOT)
# Out:
# /Users/florianb/Downloads/ai-customer-insights-engine

# %%
from streamlit_app import app as app_module

from config import config
# Out:
# 2026-07-27 14:37:56.772 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-27 14:38:03.469 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-27 14:38:03.964
# ...
#   command:
#
#     streamlit run /Users/florianb/Downloads/ai-customer-insights-engine/.venv/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-07-27 14:38:03.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-27 14:38:03.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-27 14:38:03.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import importlib

importlib.reload(config)
importlib.reload(app_module)
# Out:
# 2026-07-27 14:38:04.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-27 14:38:04.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-27 14:38:04.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-27 14:38:04.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-27 14:38:04.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-27 14:38:04.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-27 14:38:04.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
print(f"HUGGINGFACE_EMBEDDING_MODEL = {config.HUGGINGFACE_EMBEDDING_MODEL}")
print(f"LLM_MODEL = {config.LLM_MODEL}")
print(f"MAX_COMPLETION_TOKENS = {config.MAX_COMPLETION_TOKENS}")
# Out:
# HUGGINGFACE_EMBEDDING_MODEL = sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# LLM_MODEL = gpt-4o-mini
# MAX_COMPLETION_TOKENS = 300

# %% [markdown]
# ### Validation de `initialize_rag_chain()`

# %%
rag_chain = app_module.initialize_rag_chain()

# %%
response = rag_chain.invoke("Quels sont les principaux problèmes rencontrés par les clients ?")

# %%
print(response["answer"].content)

for doc in response["context"]:
    print(doc.page_content)
# Out:
# Les principaux problèmes rencontrés par les clients de Boursobank incluent :
#
# 1. **Difficulté à joindre le service client** : Plusieurs clients signalent qu'il est impossible de contacter le service client, ce qui complique la finalisation de leur inscription et la résolution de problèmes.
#
# 2. **Incompétence du service client** : Les avis mentionnent une grande incompétence du personnel, notamment en ce qui concerne la gestion des demandes et la compréhension des problèmes des clients. Les réponses fournies sont souvent jugées hors sujet.
#
# 3. **Problèmes techniques avec l'application** : Des clients rapportent que l'application ne fonctionne pas correctement, ce qui entraîne des difficultés pour effectuer des opérations bancaires.
#
# 4. **Manque de suivi des demandes** : Les clients doivent parfois envoyer plusieurs emails pour obtenir des réponses, et il n'y a pas de suivi des discussions, ce qui rend le processus frustrant.
#
# ...
